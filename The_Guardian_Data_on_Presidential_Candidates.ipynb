# %% [markdown]
# <a href="https://colab.research.google.com/github/GloBeau/AMADIFE-GLORY/blob/main/The_Guardian_Data_on_Presidential_Candidates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python Web Scraping Librabries
# BeautifulSoup is a Python library for pulling data out of HTML and XML files. 
# It creates a parse tree for parsed pages that can be used to extract data from HTML which is useful for web scraping

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import bs4
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import requests
import pandas as pd

# %%
url = "https://guardian.ng/category/news"

# %%
uClient = urlopen(url)
page_html = uClient.read()
uClient.close()

# %%
page_soup = soup(page_html, 'html.parser')
# Out:
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
containers = page_soup.findAll('div', {'class':'menu'})

# %%
filename = 'news_menu.csv'
f = open(filename, 'w')

# %%
data = requests.get(url).text

# %%
soup_object = soup(data, "html.parser")

# %%
#in html anchor/link is represented by the tag <a>
for link in soup_object.find_all('a',href=True):
  print(link.get('href'))
# Out:
# https://guardian.ng
# https://guardian.ng/
# https://www.facebook.com/guardianng
# https://www.instagram.com/guardiannigeria/
# https://twitter.com/GuardianNigeria
# https://t.me/theguardiannigeria
# https://www.youtube.com/channel/UCjV6LnXFtXzWoYxnq-zIvXw
# https://www.linkedin.com/company/guardian-newspapers-limited/
# /
# https://guardian.ng/category/news/nigeria/
# https://guardian.ng/category/news/nigeria/national/
# https://guardian.ng/category/news/nigeria/metro/
# https://guardian.ng/category/news/world/
# https://guardian.ng/category/news/world/africa/
# https://guardian.ng/category/news/world/asia/
# https://guardian.ng/category/news/world/europe/
# https://guardian.ng/category/news/world/us/
# https://guardian.ng/category/politics/
# https://guardian.ng/category/sport/
# https://guardian.ng/category/sport/football/
# https://guardian.ng/category/sport/boxing/
# https://guardian.ng/category/sport/athletics/
# https://guardian.ng/category/sport/tennis/
# ...

# %%
url = "https://guardian.ng/category/news"

# %%
data = requests.get(url).text

# %%
soup_object = soup(data, "html.parser")

# %%
def formatter(string):
  formatted = bytes(string, 'ascil').decode('unicode.escape')
  return formatted

# %%
# scrape the data by creating a function
def get_major_presidential_candidates(LP='Peter_Obi', PDP='Atiku_Abubakar', APC='Bola_Tinubu', after='2022-09-04'):
  url = 'https://guardian.ng/category/news'.format()

# %%
#pull data to get the major candidates
Peter_Obi = get_major_presidential_candidates('Peter_Obi')
Atiku_Abubakar = get_major_presidential_candidates('Atiku_Abubakar')
Bola_Tinubu = get_major_presidential_candidates('Bola_Tinubu')

#pull data of other candidates
Kwankwaso = get_major_presidential_candidates('Kwankwaso')
Omoyele_Sowore = get_major_presidential_candidates('Omoyele_Sowore')

# %%
Peter_Obi = get_major_presidential_candidates('Peter_Obi' 'sizemap')

# %%
print(Peter_Obi)
# Out:
# None

# %%
print(soup_object)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <title>Nigeria, Africa, World and Metro News — The Guardian Nigeria News – Nigeria and World News</title>
# <meta content="176502461635" property="fb:pages"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, user-scalable=no" name="viewport"/>
# <meta content="max-image-preview:large" name="robots"/>
# <!-- This site is optimized with the Yoast SEO Premium plugin v14.9 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="Find the latest breaking news on today's top stories, world news, Africa metro news and many more on Guardian Nigeria." name="description"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://editor.guardian.ng/category/news/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Guardian News" property="og:title"/>
# ...

# %%
url = 'https://guardian.ng/category/news'
url_df = pd.read_html('https://guardian.ng/category/news')
url_df.to_html('https://guardian.ng/category/news')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-f606d72f7788> in <module>
#       1 url = 'https://guardian.ng/category/news'
# ----> 2 url_df = pd.read_html('https://guardian.ng/category/news')
#       3 url_df.to_html('https://guardian.ng/category/news')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111         na_values=na_values,
#    1112         keep_default_na=keep_default_na,
# ...

# %%
url = 'https://guardian.ng/category/news'
news_data = pd.read_csv(url, error_bad_lines=False)
news_data.describe(include='all')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
news_data.isnull().sum()
# Out:
# <!DOCTYPE html>    0
# dtype: int64

# %%
news_data.groupby('Peter_Obi')['Peter_Obi'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-ad779c4be6e5> in <module>
# ----> 1 news_data.groupby('Peter_Obi')['Peter_Obi'].count()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# --> 897                 dropna=self.dropna,
#     898             )
#     899
#
# ...
